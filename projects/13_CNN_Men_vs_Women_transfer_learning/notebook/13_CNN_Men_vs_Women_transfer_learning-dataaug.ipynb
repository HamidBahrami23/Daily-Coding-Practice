# %% [markdown]
# I used Men-Women Classification Datset From Kaggle
# Link : https://www.kaggle.com/datasets/saadpd/menwomen-classification
# this one used from transfer learning + Data Augmentation

# %%
import os , shutil, pathlib
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'   # hides INFO/WARNING logs from TF C++
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
##uncomment for making dataset prepared
# original_dir = pathlib.Path(r"/home/hamid/ML/Datasets/Men-Women/traindata/traindata/")
# new_base_dir = pathlib.Path(r"/home/hamid/ML/Datasets/Men-Women-small")
# def make_subset(subset_name , start_index, end_index):
#     if (new_base_dir / subset_name).exists():
#         shutil.rmtree(new_base_dir / subset_name)
#     for category in ("men" , "women"):
#         dir = new_base_dir / subset_name / category
#         os.makedirs(dir, exist_ok=True)
#         fnames = [f"{category}.{i}.jpg"
#                  for i in range(start_index, end_index)]
#         for fname in fnames:
#             shutil.copyfile(src = original_dir / category / fname , dst = dir / fname)
# make_subset("train" , start_index = 0, end_index = 1000)
# make_subset("validation" , start_index = 1000, end_index = 1200)
# make_subset("test" , start_index = 1200, end_index = 1400)

# %%
train_dataset = image_dataset_from_directory(
    r"/home/hamid/ML/Datasets/Men-Women-small/train",
    image_size = (180 , 180),
    batch_size = 32 ,
    label_mode = "binary"
)

validation_dataset = image_dataset_from_directory(
    r"/home/hamid/ML/Datasets/Men-Women-small/validation",
    image_size = (180 , 180),
    batch_size = 32 ,
    label_mode = "binary"
)

test_dataset = image_dataset_from_directory(
    r"/home/hamid/ML/Datasets/Men-Women-small/test",
    image_size = (180 , 180),
    batch_size = 32 ,
    label_mode = "binary"
)
# Out:
# Found 2000 files belonging to 2 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765131347.332180   39681 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4181 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 400 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights = "imagenet" ,
    include_top = False , 
    input_shape = (180 , 180 , 3)
)

# %%
conv_base.trainable = False # I use it at first run

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 180, 180,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 180, 180,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 180, 180)  │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 180, 180)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 180, 180)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 180, 180,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 180, 180,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 5, 5, 512) │ 14,714,688 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,846,273 (56.63 MB)
#  Trainable params: 131,585 (514.00 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset ,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.7400 - loss: 1.3573 - val_accuracy: 0.8350 - val_loss: 0.8900
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.8280 - loss: 0.8488 - val_accuracy: 0.8350 - val_loss: 1.0408
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8325 - loss: 0.8423 - val_accuracy: 0.8375 - val_loss: 0.9322
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8345 - loss: 0.6901 - val_accuracy: 0.8175 - val_loss: 1.0153
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8430 - loss: 0.6742 - val_accuracy: 0.8000 - val_loss: 1.0515
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8460 - loss: 0.6003 - val_accuracy: 0.8325 - val_loss: 0.7848
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8340 - loss: 0.6060 - val_accuracy: 0.8250 - val_loss: 0.5503
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8340 - loss: 0.5906 - val_accuracy: 0.8075 - val_loss: 0.8274
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8375 - loss: 0.5862 - val_accuracy: 0.8600 - val_loss: 0.5695
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8510 - loss: 0.4511 - val_accuracy: 0.8400 - val_loss: 0.6373
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8600 - loss: 0.3705 - val_accuracy: 0.8400 - val_loss: 0.5609
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8630 - loss: 0.3535 - val_accuracy: 0.8275 - val_loss: 0.5469
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8665 - loss: 0.3159 - val_accuracy: 0.8425 - val_loss: 0.4622
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8550 - loss: 0.3750 - val_accuracy: 0.8275 - val_loss: 0.4895
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8680 - loss: 0.3169 - val_accuracy: 0.8325 - val_loss: 0.4553
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8670 - loss: 0.3092 - val_accuracy: 0.8500 - val_loss: 0.4183
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8735 - loss: 0.3003 - val_accuracy: 0.8350 - val_loss: 0.4301
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8795 - loss: 0.2915 - val_accuracy: 0.8375 - val_loss: 0.3992
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8650 - loss: 0.3060 - val_accuracy: 0.8400 - val_loss: 0.4170
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8680 - loss: 0.3126 - val_accuracy: 0.8450 - val_loss: 0.3995
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8745 - loss: 0.2914 - val_accuracy: 0.8500 - val_loss: 0.3877
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8745 - loss: 0.2848 - val_accuracy: 0.8450 - val_loss: 0.4076
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8755 - loss: 0.2852 - val_accuracy: 0.8500 - val_loss: 0.4102
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8785 - loss: 0.2924 - val_accuracy: 0.8525 - val_loss: 0.3831
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8805 - loss: 0.2921 - val_accuracy: 0.8375 - val_loss: 0.3902
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8735 - loss: 0.2943 - val_accuracy: 0.8425 - val_loss: 0.4111
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8765 - loss: 0.2864 - val_accuracy: 0.8325 - val_loss: 0.4123
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8755 - loss: 0.2960 - val_accuracy: 0.8275 - val_loss: 0.4052
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8840 - loss: 0.2808 - val_accuracy: 0.8375 - val_loss: 0.4580
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8770 - loss: 0.3026 - val_accuracy: 0.8450 - val_loss: 0.4167
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8765 - loss: 0.2929 - val_accuracy: 0.8450 - val_loss: 0.3966
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8890 - loss: 0.2700 - val_accuracy: 0.8525 - val_loss: 0.4121
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8775 - loss: 0.2941 - val_accuracy: 0.8450 - val_loss: 0.3979
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8760 - loss: 0.2931 - val_accuracy: 0.8550 - val_loss: 0.4382
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8885 - loss: 0.2759 - val_accuracy: 0.8475 - val_loss: 0.4075
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8795 - loss: 0.3038 - val_accuracy: 0.8525 - val_loss: 0.4093
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8860 - loss: 0.2812 - val_accuracy: 0.8300 - val_loss: 0.4346
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8800 - loss: 0.2988 - val_accuracy: 0.8400 - val_loss: 0.3831
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8790 - loss: 0.2904 - val_accuracy: 0.8350 - val_loss: 0.4027
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8890 - loss: 0.2680 - val_accuracy: 0.8450 - val_loss: 0.4378
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8820 - loss: 0.2835 - val_accuracy: 0.8425 - val_loss: 0.3918
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8750 - loss: 0.2911 - val_accuracy: 0.8550 - val_loss: 0.4214
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8825 - loss: 0.2887 - val_accuracy: 0.8325 - val_loss: 0.4165
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8755 - loss: 0.2853 - val_accuracy: 0.8475 - val_loss: 0.3996
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8825 - loss: 0.2746 - val_accuracy: 0.8250 - val_loss: 0.4453
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8760 - loss: 0.2903 - val_accuracy: 0.8300 - val_loss: 0.4179
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8785 - loss: 0.2685 - val_accuracy: 0.8400 - val_loss: 0.4365
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8875 - loss: 0.2684 - val_accuracy: 0.8375 - val_loss: 0.4180
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8785 - loss: 0.2861 - val_accuracy: 0.8425 - val_loss: 0.4181
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8855 - loss: 0.2835 - val_accuracy: 0.8375 - val_loss: 0.4368

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9075 - loss: 0.2658
# Test accuracy: 0.908

# %%
conv_base.trianable = True
for layer in conv_base.layers[:-4]:
    layer.trianable = False

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - accuracy: 0.8835 - loss: 0.2845 - val_accuracy: 0.8350 - val_loss: 0.4201
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8865 - loss: 0.2657 - val_accuracy: 0.8350 - val_loss: 0.4181
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8860 - loss: 0.2651 - val_accuracy: 0.8325 - val_loss: 0.4173
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8850 - loss: 0.2749 - val_accuracy: 0.8325 - val_loss: 0.4167
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.8885 - loss: 0.2623 - val_accuracy: 0.8325 - val_loss: 0.4166
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8830 - loss: 0.2666 - val_accuracy: 0.8325 - val_loss: 0.4152
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9020 - loss: 0.2483 - val_accuracy: 0.8325 - val_loss: 0.4150
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8885 - loss: 0.2542 - val_accuracy: 0.8325 - val_loss: 0.4139
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8980 - loss: 0.2571 - val_accuracy: 0.8300 - val_loss: 0.4141
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8910 - loss: 0.2665 - val_accuracy: 0.8325 - val_loss: 0.4141
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8920 - loss: 0.2574 - val_accuracy: 0.8325 - val_loss: 0.4136
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8900 - loss: 0.2578 - val_accuracy: 0.8375 - val_loss: 0.4136
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8935 - loss: 0.2584 - val_accuracy: 0.8325 - val_loss: 0.4128
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9010 - loss: 0.2581 - val_accuracy: 0.8350 - val_loss: 0.4124
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8855 - loss: 0.2654 - val_accuracy: 0.8325 - val_loss: 0.4136
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8960 - loss: 0.2500 - val_accuracy: 0.8400 - val_loss: 0.4134
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8980 - loss: 0.2442 - val_accuracy: 0.8350 - val_loss: 0.4136
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8740 - loss: 0.2741 - val_accuracy: 0.8400 - val_loss: 0.4121
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8965 - loss: 0.2449 - val_accuracy: 0.8400 - val_loss: 0.4129
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8960 - loss: 0.2596 - val_accuracy: 0.8400 - val_loss: 0.4122
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8840 - loss: 0.2698 - val_accuracy: 0.8400 - val_loss: 0.4116
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8905 - loss: 0.2529 - val_accuracy: 0.8400 - val_loss: 0.4110
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8925 - loss: 0.2624 - val_accuracy: 0.8425 - val_loss: 0.4098
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8765 - loss: 0.2815 - val_accuracy: 0.8400 - val_loss: 0.4091
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8905 - loss: 0.2569 - val_accuracy: 0.8400 - val_loss: 0.4093
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8980 - loss: 0.2566 - val_accuracy: 0.8425 - val_loss: 0.4086
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8920 - loss: 0.2550 - val_accuracy: 0.8425 - val_loss: 0.4089
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8950 - loss: 0.2480 - val_accuracy: 0.8450 - val_loss: 0.4095
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.8935 - loss: 0.2532 - val_accuracy: 0.8450 - val_loss: 0.4090
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8925 - loss: 0.2524 - val_accuracy: 0.8400 - val_loss: 0.4088
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8830 - loss: 0.2606 - val_accuracy: 0.8400 - val_loss: 0.4087
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8870 - loss: 0.2616 - val_accuracy: 0.8475 - val_loss: 0.4076
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8945 - loss: 0.2516 - val_accuracy: 0.8450 - val_loss: 0.4084
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8950 - loss: 0.2475 - val_accuracy: 0.8500 - val_loss: 0.4088
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8890 - loss: 0.2652 - val_accuracy: 0.8475 - val_loss: 0.4088
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8970 - loss: 0.2498 - val_accuracy: 0.8475 - val_loss: 0.4089
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8910 - loss: 0.2577 - val_accuracy: 0.8400 - val_loss: 0.4103
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8905 - loss: 0.2572 - val_accuracy: 0.8400 - val_loss: 0.4109
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9055 - loss: 0.2459 - val_accuracy: 0.8475 - val_loss: 0.4094
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8905 - loss: 0.2508 - val_accuracy: 0.8450 - val_loss: 0.4101
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8935 - loss: 0.2640 - val_accuracy: 0.8425 - val_loss: 0.4100
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8960 - loss: 0.2522 - val_accuracy: 0.8425 - val_loss: 0.4096
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.8955 - loss: 0.2456 - val_accuracy: 0.8425 - val_loss: 0.4102
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8960 - loss: 0.2567 - val_accuracy: 0.8450 - val_loss: 0.4098
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8905 - loss: 0.2546 - val_accuracy: 0.8425 - val_loss: 0.4104
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8870 - loss: 0.2653 - val_accuracy: 0.8425 - val_loss: 0.4104
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8920 - loss: 0.2465 - val_accuracy: 0.8425 - val_loss: 0.4103
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8855 - loss: 0.2592 - val_accuracy: 0.8475 - val_loss: 0.4093
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8925 - loss: 0.2523 - val_accuracy: 0.8475 - val_loss: 0.4096
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8955 - loss: 0.2567 - val_accuracy: 0.8475 - val_loss: 0.4089

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
#this is for Cleaning GPU Memory
tf.keras.backend.clear_session()
#test data
test_model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9075 - loss: 0.2701
# Test accuracy: 0.908

# %%
# ---- CONFIG ----
img_path = "/home/hamid/Downloads/Picture/test.jpg"
img_height = 180   
img_width = 180


# ---- LOAD IMAGE ----
img = tf.keras.utils.load_img(img_path, target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) 



# ---- PREDICT ----
predictions = model.predict(img_array)
score = predictions[0][0]  

if score >= 0.5:
    predicted_label = "women"
    confidence = score * 100
else:
    predicted_label = "men"
    confidence = (1 - score) * 100

plt.imshow(img)
plt.title(f"Predicted: {predicted_label} ({confidence:.2f}%)")
plt.axis("off")
plt.show()

print(f"Raw Score: {score:.4f}")
print(f"Final Prediction: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# Raw Score: 0.0602
# Final Prediction: men
